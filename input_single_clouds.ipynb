# %%
import os
import numpy as np

# %%
# level 4
LA_nir = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N4_nir.txt", "r")
LA_uv = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N4_uv.txt", "r")
LA_vis = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N4_vis.txt", "r")
rantypes = [LA_nir, LA_uv, LA_vis]
types = ['nir', 'uv', 'vis']

sizes = ['2','5','10','20','40']
for i, rantype in enumerate(rantypes):            
    type_name = types[i]
    for N in range(1):
        exp_num = N 
        rantype.seek(0)
        lines = rantype.readlines()

        for i, line in enumerate(lines):    
              
            # if "<ATMOSPHERE-LAYER-1>" in line:
            #     for z in range(72):
            #         lst = lines[i + z].split(',')
            #         #print(lst)
            #         lst[8] = str(0)
            #         lines[i + z] = ",".join(lst)
            
            if "<ATMOSPHERE-ASIZE>" in line:
                lines[i] = lines[i].replace("1", sizes[N])
    
        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/size/size/size{exp_num}/size{exp_num}_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

# %%
# level 4 without o2
LA_nir = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N4_nir.txt", "r")
LA_uv = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N4_uv.txt", "r")
LA_vis = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N4_vis.txt", "r")
rantypes = [LA_nir, LA_uv, LA_vis]
types = ['nir', 'uv', 'vis']

sizes = ['2','5','10','20','40']
for i, rantype in enumerate(rantypes):            
    type_name = types[i]
    for N in range(1):
        exp_num = N 
        rantype.seek(0)
        lines = rantype.readlines()

        for i, line in enumerate(lines):    
              
            if "<ATMOSPHERE-LAYER-1>" in line:
                for z in range(72):
                    lst = lines[i + z].split(',')
                    #print(lst)
                    lst[8] = str(0)
                    lines[i + z] = ",".join(lst)
            
            if "<ATMOSPHERE-ASIZE>" in line:
                lines[i] = lines[i].replace("1", sizes[N])
    
        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/size/size_without_o2/size{exp_num}/size{exp_num}_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

# %%
# level 4 without o3
LA_nir = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N4_nir.txt", "r")
LA_uv = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N4_uv.txt", "r")
LA_vis = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N4_vis.txt", "r")
rantypes = [LA_nir, LA_uv, LA_vis]
types = ['nir', 'uv', 'vis']

sizes = ['2','5','10','20','40']
for i, rantype in enumerate(rantypes):            
    type_name = types[i]
    for N in range(1):
        exp_num = N
        rantype.seek(0)
        lines = rantype.readlines()

        for i, line in enumerate(lines):    
              
            if "<ATMOSPHERE-LAYER-1>" in line:
                for z in range(72):
                    lst = lines[i + z].split(',')
                    #print(lst)
                    lst[4] = str(0)
                    lines[i + z] = ",".join(lst)
            
            if "<ATMOSPHERE-ASIZE>" in line:
                lines[i] = lines[i].replace("1", sizes[N])
    
        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/size/size_without_o3/size{exp_num}/size{exp_num}_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

# %%
# level 14
LA_nir = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N14_nir.txt", "r")
LA_uv = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N14_uv.txt", "r")
LA_vis = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N14_vis.txt", "r")
rantypes = [LA_nir, LA_uv, LA_vis]
types = ['nir', 'uv', 'vis']

sizes = ['2','5','10','20','40']
for i, rantype in enumerate(rantypes):            
    type_name = types[i]
    for N in range(1):
        exp_num = N
        rantype.seek(0)
        lines = rantype.readlines()

        for i, line in enumerate(lines):    
              
            # if "<ATMOSPHERE-LAYER-1>" in line:
            #     for z in range(72):
            #         lst = lines[i + z].split(',')
            #         #print(lst)
            #         lst[8] = str(0)
            #         lines[i + z] = ",".join(lst)
            
            if "<ATMOSPHERE-ASIZE>" in line:
                lines[i] = lines[i].replace("1", sizes[N])
    
        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/size/size/size{exp_num}/size14_{exp_num}_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

# %%
# level 14 without o2
LA_nir = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N14_nir.txt", "r")
LA_uv = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N14_uv.txt", "r")
LA_vis = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N14_vis.txt", "r")
rantypes = [LA_nir, LA_uv, LA_vis]
types = ['nir', 'uv', 'vis']

sizes = ['2','5','10','20','40']
for i, rantype in enumerate(rantypes):            
    type_name = types[i]
    for N in range(1):
        exp_num = N 
        rantype.seek(0)
        lines = rantype.readlines()

        for i, line in enumerate(lines):    
              
            if "<ATMOSPHERE-LAYER-1>" in line:
                for z in range(72):
                    lst = lines[i + z].split(',')
                    #print(lst)
                    lst[8] = str(0)
                    lines[i + z] = ",".join(lst)
            
            if "<ATMOSPHERE-ASIZE>" in line:
                lines[i] = lines[i].replace("1", sizes[N])
    
        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/size/size_without_o2/size{exp_num}/size14_{exp_num}_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

# %%
# level 14 without o3
LA_nir = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N14_nir.txt", "r")
LA_uv = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N14_uv.txt", "r")
LA_vis = open("/Users/jeffyang/Desktop/PSG/size/basefiles/mmr_N14_vis.txt", "r")
rantypes = [LA_nir, LA_uv, LA_vis]
types = ['nir', 'uv', 'vis']

sizes = ['2','5','10','20','40']
for i, rantype in enumerate(rantypes):            
    type_name = types[i]
    for N in range(1):
        exp_num = N
        rantype.seek(0)
        lines = rantype.readlines()

        for i, line in enumerate(lines):    
              
            if "<ATMOSPHERE-LAYER-1>" in line:
                for z in range(72):
                    lst = lines[i + z].split(',')
                    #print(lst)
                    lst[4] = str(0)
                    lines[i + z] = ",".join(lst)
            
            if "<ATMOSPHERE-ASIZE>" in line:
                lines[i] = lines[i].replace("1", sizes[N])
    
        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/size/size_without_o3/size{exp_num}/size14_{exp_num}_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

# %%
# clsky no o2
LA_nir = open("/Users/jeffyang/Desktop/PSG/clearsky/mmr_N1_nir.txt", "r")
LA_uv = open("/Users/jeffyang/Desktop/PSG/clearsky/mmr_N1_uv.txt", "r")
LA_vis = open("/Users/jeffyang/Desktop/PSG/clearsky/mmr_N1_vis.txt", "r")
rantypes = [LA_nir, LA_uv, LA_vis]
types = ['nir', 'uv', 'vis']

for i, rantype in enumerate(rantypes):            
    type_name = types[i]
    for N in range(1):
        rantype.seek(0)
        lines = rantype.readlines()
        for i, line in enumerate(lines):    
            if "<ATMOSPHERE-LAYER-1>" in line:
                for z in range(72):
                    lst = lines[i + z].split(',')
                    lst[8] = str(0)
                    lines[i + z] = ",".join(lst)
            
        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/clearsky_o2/mmr_N1_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

# %%
# clsky no o3
LA_nir = open("/Users/jeffyang/Desktop/PSG/clearsky/mmr_N1_nir.txt", "r")
LA_uv = open("/Users/jeffyang/Desktop/PSG/clearsky/mmr_N1_uv.txt", "r")
LA_vis = open("/Users/jeffyang/Desktop/PSG/clearsky/mmr_N1_vis.txt", "r")
rantypes = [LA_nir, LA_uv, LA_vis]
types = ['nir', 'uv', 'vis']

for i, rantype in enumerate(rantypes):            
    type_name = types[i]
    for N in range(1):
        rantype.seek(0)
        lines = rantype.readlines()
        for i, line in enumerate(lines):    
            if "<ATMOSPHERE-LAYER-1>" in line:
                for z in range(72):
                    lst = lines[i + z].split(',')
                    lst[4] = str(0)
                    lines[i + z] = ",".join(lst)
            
        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/clearsky_o3/mmr_N1_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

# %%
mklst_clouddata = os.listdir('/Users/jeffyang/Desktop/PSG/CARMA_input/post_interpolation_data')
pre_ip = "/Users/jeffyang/Desktop/PSG/CARMA_input/post_interpolation_data/"
clouddata = []
for file in mklst_clouddata:
    if file.endswith('.npy'):
        print(file)
        clouddata.append(file)
print(clouddata)
# Out:
# interpolation29.npy
# interpolation15.npy
# interpolation7.npy
# interpolation14.npy
# interpolation6.npy
# interpolation28.npy
# interpolation4.npy
# interpolation16.npy
# interpolation5.npy
# interpolation17.npy
# interpolation13.npy
# interpolation1.npy
# interpolation12.npy
# interpolation0.npy
# interpolation2.npy
# interpolation10.npy
# interpolation38.npy
# interpolation39.npy
# interpolation3.npy
# interpolation11.npy
# interpolation49.npy
# interpolation48.npy
# interpolation43.npy
# interpolation42.npy
# interpolation40.npy
# interpolation41.npy
# interpolation45.npy
# interpolation44.npy
# interpolation46.npy
# interpolation47.npy
# interpolation20.npy
# interpolation34.npy
# interpolation35.npy
# interpolation21.npy
# interpolation37.npy
# interpolation23.npy
# interpolation22.npy
# interpolation36.npy
# interpolation32.npy
# interpolation26.npy
# interpolation8.npy
# interpolation9.npy
# interpolation27.npy
# interpolation33.npy
# interpolation25.npy
# ...

# %%
clouddata
# Out:
# ['inerpolation1.npy',
#  'inerpolation2.npy',
#  'inerpolation3.npy',
#  'inerpolation4.npy',
#  'inerpolation5.npy',
#  'inerpolation6.npy',
#  'inerpolation7.npy',
#  'inerpolation8.npy',
#  'inerpolation9.npy',
#  'inerpolation10.npy',
#  'inerpolation11.npy',
#  'inerpolation12.npy',
#  'inerpolation13.npy',
#  'inerpolation14.npy',
#  'inerpolation15.npy',
#  'inerpolation16.npy',
#  'inerpolation17.npy',
#  'inerpolation18.npy',
#  'inerpolation19.npy',
#  'inerpolation20.npy',
#  'inerpolation21.npy',
#  'inerpolation22.npy',
#  'inerpolation23.npy',
#  'inerpolation24.npy',
#  'inerpolation25.npy',
#  'inerpolation26.npy',
#  'inerpolation27.npy',
#  'inerpolation28.npy',
#  'inerpolation29.npy',
#  'inerpolation30.npy',
#  'inerpolation31.npy',
#  'inerpolation32.npy',
#  'inerpolation33.npy',
#  'inerpolation34.npy',
#  'inerpolation35.npy',
#  'inerpolation36.npy',
#  'inerpolation37.npy',
#  'inerpolation38.npy',
#  'inerpolation39.npy',
#  'inerpolation40.npy',
# ...

# %%
clouddata  = []
for i in range(50):
    clouddata  = clouddata+['interpolation'+str(i)+'.npy']

# %%
# generated specified number of sizes (bin)
for type_name in ("nir", "uv", "vis"):
    LA_nir = open("/Users/jeffyang/Desktop/PSG/CARMA_input/basefiles/psg_test_input_nir.txt", "r")
    LA_uv = open("/Users/jeffyang/Desktop/PSG/CARMA_input/basefiles/psg_test_input_uv.txt", "r")
    LA_vis = open("/Users/jeffyang/Desktop/PSG/CARMA_input/basefiles/psg_test_input_vis.txt", "r")

    rantypes = [LA_nir, LA_uv, LA_vis]
    types = ['nir', 'uv', 'vis']

    # CLOUD_THICKNESS = 6e-2 
    # FIRST_LEVEL_P = 1.0028e+00
    N = 17
    for irant, rantype in enumerate(rantypes):            
        type_name = types[irant]
        lines = rantype.readlines()

        for i, line in enumerate(lines):

            if "<ATMOSPHERE-LAYERS-MOLECULES>" in line:
                lines[i] = lines[i].replace("<ATMOSPHERE-LAYERS-MOLECULES>","") #NOTE: Strings are immutable; the code "lines[i].replace("\n",",")" thus won't execute
                initline = "<ATMOSPHERE-LAYERS-MOLECULES>"     
                for j in range(N):
                    # lines[i] = lines[i] + "WaterIce" + str(j) + ","
                    initline = initline + "WaterIce" + str(j) + ","
                lines[i] =  initline + lines[i] 

                # lines[i] = (lines[i])[:-1]
                # lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-LAYER-1>" in line:

                for z in range(72):
                    lst = lines[i + z].split(',')
                    # lst[8] = str(0) 
                    for k in range(N-1):
                        mmr = 0
                        for ifile in range(3):
                            file = np.load(pre_ip + clouddata[3*k+ifile])
                            mmr = mmr + file[z]
                        lst.insert(2+k,"{:.2e}".format(mmr))
                    mmr = 0
                    for ifile in range(2):
                            file = np.load(pre_ip + clouddata[3*(N-1)+ifile])
                            mmr = mmr + file[z]
                    lst.insert(2+N-1,"{:.2e}".format(mmr))
                    lines[i + z] = ",".join(lst)
                
                # # print(i)
                # for z in range(72):
                #     lines[i+z] = lines[i+z].replace("<ATMOSPHERE-LAYER-"+str(z+1)+">","") #NOTE: Strings are immutable; the code "lines[i].replace("\n",",")" thus won't execute
                #     initline = "<ATMOSPHERE-LAYER-"+str(z+1)+">"
                #     for k in range(N-1):
                #         mmr = 0
                #         for ifile in range(3):
                #             file = np.load(pre_ip + clouddata[3*k+ifile])
                #             mmr = mmr + file[z]
                #         initline = initline + "{:.2e}".format(mmr) + ","
                #     mmr = 0
                #     for ifile in range(2):
                #             file = np.load(pre_ip + clouddata[48+ifile])
                #             mmr = mmr + file[z]
                #     initline = initline + "{:.2e}".format(mmr)
                #     # for k, file_name in enumerate(clouddata): #clouddata: 50 bins
                #     #     if k < N:
                #     #         file = np.load(pre_ip + file_name)
                #     #         lines[i+z] = lines[i+z] + str(file[z]) + ","
                #     # lines[i+z] = (lines[i+z])[:-1]
                #     lines[i+z] = initline + lines[i+z]
            
            if "<ATMOSPHERE-NAERO>" in line:
                lines[i] = lines[i].replace("1\n", f"{N}\n")

            if "<ATMOSPHERE-AEROS>" in line:
                lines[i] = lines[i].replace("WaterIce\n", "")
                for j in range(N):
                    lines[i] = lines[i] + "WaterIce"+ str(j) + ","
                lines[i] = (lines[i])[:-1]
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-AABUN>" in line:
                lines[i] = lines[i].replace("1\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "1,"
                lines[i] = lines[i] + "1"
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-AUNIT>" in line:
                lines[i] = lines[i].replace("scl\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "scl,"
                lines[i] = lines[i] + "scl"
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-ASIZE>" in line:
                lines[i] = lines[i].replace("1\n", "")
                for k in range(N-1):
                    size = 1
                    for ifile in range(3):
                        file = np.load(pre_ip + clouddata[3*k+ifile])
                        size = size * file[72]
                    size = size**(1/3)
                    lines[i] = lines[i] + "{:.2e}".format(size) + ","
                size = 1
                for ifile in range(2):
                    file = np.load(pre_ip + clouddata[3*(N-1)+ifile])
                    # file = np.load(pre_ip + clouddata[48+ifile])

                    size = size * file[72]
                size = size**(1/2)
                lines[i] = lines[i] + "{:.2e}".format(size)
                # for k, file_name in enumerate(clouddata): #clouddata: 50 bins
                #     if k < N:
                #         file = np.load(pre_ip + file_name)
                #         lines[i+z] = lines[i+z] + str(file[z]) + ","
                # lines[i+z] = (lines[i+z])[:-1]
                lines[i] = lines[i] + "\n"

                # for x, file_name in enumerate(clouddata):
                #     if x < N:
                #         file = np.load(pre_ip + file_name)
                #         lines[i] = lines[i] + str(file[72]) + ","
                # lines[i] = (lines[i])[:-1]
                # lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-ASUNI>" in line:
                lines[i] = lines[i].replace("um\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "um,"
                lines[i] = lines[i] + "um"
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-ATYPE>" in line:
                lines[i] = lines[i].replace("AFCRL_Ice_HRI\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "AFCRL_Ice_HRI,"
                lines[i] = lines[i] + "AFCRL_Ice_HRI"
                lines[i] = lines[i] + "\n"

        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/CARMA_input/CARMA_liq/augmented_input_file_{N}bins_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

    # f = open(f"/Users/michellehu/Downloads/PSG_cloud_project_copy/augmented_input_file_{N}bins_{type_name}.txt","r")                
    # print(f.read())

# %%
# CARMA_no_o2
for type_name in ("nir", "uv", "vis"):
    LA_nir = open("/Users/jeffyang/Desktop/PSG/CARMA_input/basefiles/psg_test_input_nir.txt", "r")
    LA_uv = open("/Users/jeffyang/Desktop/PSG/CARMA_input/basefiles/psg_test_input_uv.txt", "r")
    LA_vis = open("/Users/jeffyang/Desktop/PSG/CARMA_input/basefiles/psg_test_input_vis.txt", "r")

    rantypes = [LA_nir, LA_uv, LA_vis]
    types = ['nir', 'uv', 'vis']

    # CLOUD_THICKNESS = 6e-2 
    # FIRST_LEVEL_P = 1.0028e+00
    N = 17
    for irant, rantype in enumerate(rantypes):            
        type_name = types[irant]
        lines = rantype.readlines()

        for i, line in enumerate(lines):

            if "<ATMOSPHERE-LAYERS-MOLECULES>" in line:
                lines[i] = lines[i].replace("\n",",") #NOTE: Strings are immutable; the code "lines[i].replace("\n",",")" thus won't execute       
                for j in range(N):
                    lines[i] = lines[i] + "WaterIce" + str(j) + ","
                lines[i] = (lines[i])[:-1]
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-LAYER-1>" in line:
                # print(i)
                for z in range(72):
                    lines[i+z] = lines[i+z].replace("\n", ",") 
                    for k in range(N-1):
                        mmr = 0
                        for ifile in range(3):
                            file = np.load(pre_ip + clouddata[3*k+ifile])
                            mmr = mmr + file[z]
                        lines[i+z] = lines[i+z] + "{:.2e}".format(mmr) + ","
                    mmr = 0
                    for ifile in range(2):
                            file = np.load(pre_ip + clouddata[3*(N-1)+ifile])
                            mmr = mmr + file[z]
                    lines[i+z] = lines[i+z] + "{:.2e}".format(mmr)
                    # for k, file_name in enumerate(clouddata): #clouddata: 50 bins
                    #     if k < N:
                    #         file = np.load(pre_ip + file_name)
                    #         lines[i+z] = lines[i+z] + str(file[z]) + ","
                    # lines[i+z] = (lines[i+z])[:-1]
                    lines[i+z] = lines[i+z] + "\n"


            if "<ATMOSPHERE-LAYER-1>" in line:
                for z in range(72):
                    lst = lines[i + z].split(',')
                    lst[8] = str(0)
                    lines[i + z] = ",".join(lst)

            if "<ATMOSPHERE-NAERO>" in line:
                lines[i] = lines[i].replace("1\n", f"{N}\n")

            if "<ATMOSPHERE-AEROS>" in line:
                lines[i] = lines[i].replace("WaterIce\n", "")
                for j in range(N):
                    lines[i] = lines[i] + "WaterIce" + ","
                lines[i] = (lines[i])[:-1]
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-AABUN>" in line:
                lines[i] = lines[i].replace("1\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "1,"
                lines[i] = lines[i] + "1"
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-AUNIT>" in line:
                lines[i] = lines[i].replace("scl\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "scl,"
                lines[i] = lines[i] + "scl"
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-ASIZE>" in line:
                lines[i] = lines[i].replace("1\n", "")
                for k in range(N-1):
                    size = 1
                    for ifile in range(3):
                        file = np.load(pre_ip + clouddata[3*k+ifile])
                        size = size * file[72]
                    size = size**(1/3)
                    lines[i] = lines[i] + "{:.2e}".format(size) + ","
                size = 1
                for ifile in range(2):
                    file = np.load(pre_ip + clouddata[48+ifile])
                    size = size * file[72]
                size = size**(1/2)
                lines[i] = lines[i] + "{:.2e}".format(size)
                # for k, file_name in enumerate(clouddata): #clouddata: 50 bins
                #     if k < N:
                #         file = np.load(pre_ip + file_name)
                #         lines[i+z] = lines[i+z] + str(file[z]) + ","
                # lines[i+z] = (lines[i+z])[:-1]
                lines[i] = lines[i] + "\n"

                # for x, file_name in enumerate(clouddata):
                #     if x < N:
                #         file = np.load(pre_ip + file_name)
                #         lines[i] = lines[i] + str(file[72]) + ","
                # lines[i] = (lines[i])[:-1]
                # lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-ASUNI>" in line:
                lines[i] = lines[i].replace("um\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "um,"
                lines[i] = lines[i] + "um"
                lines[i] = lines[i] + "\n"
                
            if "<ATMOSPHERE-ATYPE>" in line:
                lines[i] = lines[i].replace("AFCRL_Ice_HRI\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "AFCRL_Ice_HRI,"
                lines[i] = lines[i] + "AFCRL_Ice_HRI"
                lines[i] = lines[i] + "\n"


        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/CARMA_input/CARMA_liq_o2/augmented_input_file_{N}bins_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

    # f = open(f"/Users/michellehu/Downloads/PSG_cloud_project_copy/augmented_input_file_{N}bins_{type_name}.txt","r")                
    # print(f.read())

# %%
# CARMA_no_o2
for type_name in ("nir", "uv", "vis"):
    LA_nir = open("/Users/jeffyang/Desktop/PSG/CARMA_input/basefiles/psg_test_input_nir.txt", "r")
    LA_uv = open("/Users/jeffyang/Desktop/PSG/CARMA_input/basefiles/psg_test_input_uv.txt", "r")
    LA_vis = open("/Users/jeffyang/Desktop/PSG/CARMA_input/basefiles/psg_test_input_vis.txt", "r")

    rantypes = [LA_nir, LA_uv, LA_vis]
    types = ['nir', 'uv', 'vis']

    # CLOUD_THICKNESS = 6e-2 
    # FIRST_LEVEL_P = 1.0028e+00
    N = 17
    for irant, rantype in enumerate(rantypes):            
        type_name = types[irant]
        lines = rantype.readlines()

        for i, line in enumerate(lines):

            if "<ATMOSPHERE-LAYERS-MOLECULES>" in line:
                lines[i] = lines[i].replace("\n",",") #NOTE: Strings are immutable; the code "lines[i].replace("\n",",")" thus won't execute       
                for j in range(N):
                    lines[i] = lines[i] + "WaterIce" + str(j) + ","
                lines[i] = (lines[i])[:-1]
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-LAYER-1>" in line:
                # print(i)
                for z in range(72):
                    lines[i+z] = lines[i+z].replace("\n", ",") 
                    for k in range(N-1):
                        mmr = 0
                        for ifile in range(3):
                            file = np.load(pre_ip + clouddata[3*k+ifile])
                            mmr = mmr + file[z]
                        lines[i+z] = lines[i+z] + "{:.2e}".format(mmr) + ","
                    mmr = 0
                    for ifile in range(2):
                            file = np.load(pre_ip + clouddata[48+ifile])
                            mmr = mmr + file[z]
                    lines[i+z] = lines[i+z] + "{:.2e}".format(mmr)
                    # for k, file_name in enumerate(clouddata): #clouddata: 50 bins
                    #     if k < N:
                    #         file = np.load(pre_ip + file_name)
                    #         lines[i+z] = lines[i+z] + str(file[z]) + ","
                    # lines[i+z] = (lines[i+z])[:-1]
                    lines[i+z] = lines[i+z] + "\n"


            if "<ATMOSPHERE-LAYER-1>" in line:
                for z in range(72):
                    lst = lines[i + z].split(',')
                    lst[4] = str(0)
                    lines[i + z] = ",".join(lst)

            if "<ATMOSPHERE-NAERO>" in line:
                lines[i] = lines[i].replace("1\n", f"{N}\n")

            if "<ATMOSPHERE-AEROS>" in line:
                lines[i] = lines[i].replace("WaterIce\n", "")
                for j in range(N):
                    lines[i] = lines[i] + "WaterIce" + ","
                lines[i] = (lines[i])[:-1]
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-AABUN>" in line:
                lines[i] = lines[i].replace("1\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "1,"
                lines[i] = lines[i] + "1"
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-AUNIT>" in line:
                lines[i] = lines[i].replace("scl\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "scl,"
                lines[i] = lines[i] + "scl"
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-ASIZE>" in line:
                lines[i] = lines[i].replace("1\n", "")
                for k in range(N-1):
                    size = 1
                    for ifile in range(3):
                        file = np.load(pre_ip + clouddata[3*k+ifile])
                        size = size * file[72]
                    size = size**(1/3)
                    lines[i] = lines[i] + "{:.2e}".format(size) + ","
                size = 1
                for ifile in range(2):
                    file = np.load(pre_ip + clouddata[48+ifile])
                    size = size * file[72]
                size = size**(1/2)
                lines[i] = lines[i] + "{:.2e}".format(size)
                # for k, file_name in enumerate(clouddata): #clouddata: 50 bins
                #     if k < N:
                #         file = np.load(pre_ip + file_name)
                #         lines[i+z] = lines[i+z] + str(file[z]) + ","
                # lines[i+z] = (lines[i+z])[:-1]
                lines[i] = lines[i] + "\n"

                # for x, file_name in enumerate(clouddata):
                #     if x < N:
                #         file = np.load(pre_ip + file_name)
                #         lines[i] = lines[i] + str(file[72]) + ","
                # lines[i] = (lines[i])[:-1]
                # lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-ASUNI>" in line:
                lines[i] = lines[i].replace("um\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "um,"
                lines[i] = lines[i] + "um"
                lines[i] = lines[i] + "\n"

            if "<ATMOSPHERE-ATYPE>" in line:
                lines[i] = lines[i].replace("AFCRL_Ice_HRI\n", "")
                for x in range(N-1):
                    lines[i] = lines[i] + "AFCRL_Ice_HRI,"
                lines[i] = lines[i] + "AFCRL_Ice_HRI"
                lines[i] = lines[i] + "\n"

        augmented_input_file = open(f"/Users/jeffyang/Desktop/PSG/CARMA_input/CARMA_liq_o3/augmented_input_file_{N}bins_{type_name}.txt","w")
        augmented_input_file.writelines(lines)
        augmented_input_file.close()

    # f = open(f"/Users/michellehu/Downloads/PSG_cloud_project_copy/augmented_input_file_{N}bins_{type_name}.txt","r")                
    # print(f.read())

# %%
file[72]
# Out:
# 2130.0
